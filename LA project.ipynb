# %%
import csv
import pandas as pd

# %%
df = pd.read_csv('parking-citations.csv')
# Out:
# C:\Users\Aihua Chen\anaconda\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (0,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.sample(n=10)
# Out:
#         Ticket number           Issue Date  Issue time Meter Id  Marked Time  \
# 6932077    4325962782  2018-02-05T00:00:00      1439.0      NaN          NaN
# 6013851    4315411306  2017-09-09T00:00:00      1335.0    OS312          NaN
# 5902715    4314695711  2017-08-22T00:00:00      1056.0      NaN          NaN
# 5174663    4307358462  2017-04-24T00:00:00      1129.0      NaN          NaN
# 4387066    4299191002  2016-12-19T00:00:00      1724.0    SS288          NaN
# 5158757    4307111174  2017-04-26T00:00:00      1311.0      NaN       1036.0
# 2027921    1111737303  2015-05-05T00:00:00      1301.0      NaN          NaN
# 2507395    4262997830  2015-07-24T00:00:00      1200.0      161          NaN
# 7531698    4331793395  2018-05-22T00:00:00       812.0      NaN          NaN
# 7542099    4332525750  2018-05-23T00:00:00      1059.0      NaN        849.0
#
#         RP State Plate  Plate Expiry Date  VIN  Make Body Style Color  \
# ...

# %%
df['year'] = df['Issue Date'].map(lambda x: str(x).split('-')[0])
df.head()
# Out:
#   Ticket number           Issue Date  Issue time Meter Id  Marked Time  \
# 0    1103341116  2015-12-21T00:00:00      1251.0      NaN          NaN
# 1    1103700150  2015-12-21T00:00:00      1435.0      NaN          NaN
# 2    1104803000  2015-12-21T00:00:00      2055.0      NaN          NaN
# 3    1104820732  2015-12-26T00:00:00      1515.0      NaN          NaN
# 4    1105461453  2015-09-15T00:00:00       115.0      NaN          NaN
#
#   RP State Plate  Plate Expiry Date  VIN  Make Body Style Color  \
# 0             CA           200304.0  NaN  HOND         PA    GY
# 1             CA           201512.0  NaN   GMC         VN    WH
# 2             CA           201503.0  NaN  NISS         PA    BK
# 3             CA                NaN  NaN  ACUR         PA    WH
# 4             CA           200316.0  NaN  CHEV         PA    BK
#
#              Location  Route  Agency Violation code Violation Description  \
# 0     13147 WELBY WAY  01521     1.0         4000A1    NO EVIDENCE OF REG
# ...

# %%
df_1 = df[df['year'] == "2018"]

# %%
df_1.head()
df_1.shape
# Out:
# (1997938, 20)

# %%
df_1.to_csv('out_csv')

# %%
df_1.head(100)
# Out:
#         Ticket number           Issue Date  Issue time Meter Id  Marked Time  \
# 4044488    4320468924  2018-01-13T00:00:00        26.0      NaN          NaN
# 4044489    4320468935  2018-01-13T00:00:00        27.0      NaN          NaN
# 4044490    4320468946  2018-01-13T00:00:00        27.0      NaN          NaN
# 4044491    4320468950  2018-01-13T00:00:00        28.0      NaN          NaN
# 4044492    4320468961  2018-01-13T00:00:00        29.0      NaN          NaN
# 4044493    4320468972  2018-01-13T00:00:00        30.0      NaN          NaN
# 4044494    4320468983  2018-01-13T00:00:00        30.0      NaN          NaN
# 4044495    4320468994  2018-01-13T00:00:00        33.0      NaN          NaN
# 4044496    4320469005  2018-01-13T00:00:00        35.0      NaN          NaN
# 4044497    4320469016  2018-01-13T00:00:00        35.0      NaN          NaN
# 4044498    4320469020  2018-01-13T00:00:00        45.0      NaN          NaN
# ...

# %%
for i in range(10):
    print(list(df_1["Latitude"])[i])
# Out:
# 6499186.18615
# 6499186.18615
# 6499186.18615
# 6499186.18615
# 6499186.18615
# 6499186.18615
# 6499186.18615
# 6499506.15678
# 6499506.15678
# 6499506.15678

# %%
df_1['Ticket number'].nunique()
# Out:
# 1997938

# %%
df_1.shape
# Out:
# (1997938, 20)

# %%
df_1['Issue time'].max()
# Out:
# 2359.0

# %%
df_1.groupby('Meter Id').count()
# Out:
#           Ticket number  Issue Date  Issue time  Marked Time  RP State Plate  \
# Meter Id
# %!                    1           1           1            0               1
# .32                   1           1           1            0               1
# .36                   1           1           1            0               1
# .37                   1           1           1            0               1
# .7                    1           1           1            0               1
# 00                  226         226         226            0             226
# 001                 263         263         263            0             263
# 01                  414         414         414            0             414
# 018                   1           1           1            0               1
# 02                   67          67          67            0              67
# 026                   2           2           2            0               2
# ...

# %%
# df['Meter Id'].value_counts()[NaN]
df_1.isnull().sum()
# Out:
# Ticket number                  0
# Issue Date                     0
# Issue time                   529
# Meter Id                 1530794
# Marked Time              1935333
# RP State Plate                 0
# Plate Expiry Date         193830
# VIN                      1997938
# Make                        1839
# Body Style                  2218
# Color                        915
# Location                      91
# Route                      15248
# Agency                         4
# Violation code                 0
# Violation Description        263
# Fine amount                 1649
# Latitude                       2
# Longitude                      2
# year                           0
# dtype: int64
